# %%
from numpy.random import randn

# %%
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/yunsungsong/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/yunsungsong/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
sns.set_palette("hls")

# %%
mpl.rc("figure", figsize=(10,6))

# %%
data = randn(250)

# %%
plt.title("KDE Demonstration using Seaborn and Matplotlib", fontsize =20)
# Out:
# Text(0.5,1,'KDE Demonstration using Seaborn and Matplotlib')

# %%
sns.distplot(data, color='#ff8000')
# Out:
# /Users/yunsungsong/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
