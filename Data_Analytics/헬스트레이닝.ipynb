# %%
## Data structure
## 1. series 2. Data Frame
import pandas as pd

# %%
train = pd.read_csv("tkx-user-data.csv")

# %%
print(train.shape)
train
# Out:
# (106839, 13)
#          이름      성별           전화번호    나이  현재 체중  목표 체중       키         회원 가입일  \
# 0       안원준      남성  010-2292-6251   31세     78     68     176  2016년 07월 05일
# 1       유세아      여성    01045795881    39   56kg   51kg     172  2016년 10월 02일
# 2       송솔은      여성  010-7719-8346   NaN     29     21     167  2017년 09월 06일
# 3       백서원      여성    01011947169    36     67     65       0  2017년 06월 02일
# 4       박서은      여성  010-2575-6398    42     60     57     167  2017년 05월 07일
# 5       전재성      남성  010-7299-1288    39     76     73     171  2017년 12월 01일
# 6       유수애      여성  010-2132-4484   NaN      0      0     177  2016년 12월 05일
# 7       허태연    Male    01019249265    32  83 kg  78 kg       0  2016년 10월 25일
# 8       윤소현  female    01045337615    27     60     58       0  2017년 08월 24일
# 9       황윤일    male    01036423916    29     76     70     171  2017년 11월 04일
# 10      한대권      남성        unknown    37     78     69       0  2016년 04월 10일
# ...
