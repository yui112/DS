# %%
import pandas as pd
import numpy as np

# %%
college = pd.read_csv('../data/college.csv', index_col='INSTNM')
city = college['CITY']
city.head()
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# Name: CITY, dtype: object

# %%
city.iloc[3]
# Out:
# 'Huntsville'

# %%
city.iloc[[10, 20, 30]]
# Out:
# INSTNM
# Birmingham Southern College                            Birmingham
# George C Wallace State Community College-Hanceville    Hanceville
# Judson College                                             Marion
# Name: CITY, dtype: object

# %%
city.iloc[4:50:10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %%
city.loc['Heritage Christian University']
# Out:
# 'Florence'

# %%
np.random.seed(1)

# %%
labels = list(np.random.choice(city.index, 4))

# %%
labels
# Out:
# ['Northwest HVAC/R Training Center',
#  'California State University-Dominguez Hills',
#  'Lower Columbia College',
#  'Southwest Acupuncture College-Boulder']

# %%
city.loc[labels]
# Out:
# INSTNM
# Northwest HVAC/R Training Center                Spokane
# California State University-Dominguez Hills      Carson
# Lower Columbia College                         Longview
# Southwest Acupuncture College-Boulder           Boulder
# Name: CITY, dtype: object

# %%
college.iloc[60]
# Out:
# CITY                  Anchorage
# STABBR                       AK
# HBCU                          0
# MENONLY                       0
# WOMENONLY                     0
# RELAFFIL                      0
# SATVRMID                    NaN
# SATMTMID                    NaN
# DISTANCEONLY                  0
# UGDS                      12865
# UGDS_WHITE               0.5747
# UGDS_BLACK               0.0358
# UGDS_HISP                0.0761
# UGDS_ASIAN               0.0778
# UGDS_AIAN                0.0653
# UGDS_NHPI                0.0086
# UGDS_2MOR                 0.098
# UGDS_NRA                 0.0181
# UGDS_UNKN                0.0457
# PPTUG_EF                 0.4539
# CURROPER                      1
# PCTPELL                  0.2385
# PCTFLOAN                 0.2647
# UG25ABV                  0.4386
# MD_EARN_WNE_P10           42500
# GRAD_DEBT_MDN_SUPP      19449.5
# Name: University of Alaska Anchorage, dtype: object

# %%
college.iloc[[60, 93, 30]]
# Out:
#                                         CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# INSTNM
# University of Alaska Anchorage     Anchorage     AK   0.0      0.0        0.0
# Avalon School of Cosmetology-Mesa       Mesa     AZ   0.0      0.0        0.0
# Judson College                        Marion     AL   0.0      0.0        1.0
#
#                                    RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# University of Alaska Anchorage            0       NaN       NaN           0.0
# Avalon School of Cosmetology-Mesa         0       NaN       NaN           0.0
# Judson College                            1       NaN       NaN           0.0
#
#                                       UGDS         ...          UGDS_2MOR  \
# INSTNM                                             ...
# University of Alaska Anchorage     12865.0         ...             0.0980
# Avalon School of Cosmetology-Mesa    360.0         ...             0.0250
# ...

# %%
college.loc[['University of Alaska Anchorage', 'Avalon School of Cosmetology-Mesa']]
# Out:
#                                         CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# INSTNM
# University of Alaska Anchorage     Anchorage     AK   0.0      0.0        0.0
# Avalon School of Cosmetology-Mesa       Mesa     AZ   0.0      0.0        0.0
#
#                                    RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# University of Alaska Anchorage            0       NaN       NaN           0.0
# Avalon School of Cosmetology-Mesa         0       NaN       NaN           0.0
#
#                                       UGDS         ...          UGDS_2MOR  \
# INSTNM                                             ...
# University of Alaska Anchorage     12865.0         ...              0.098
# Avalon School of Cosmetology-Mesa    360.0         ...              0.025
#
#                                    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# University of Alaska Anchorage       0.0181     0.0457    0.4539         1
# ...

# %%
lables = [['University of Alaska Anchorage', 'Avalon School of Cosmetology-Mesa']]

# %%
college.loc[['University of Alaska Anchorage', 'Avalon School of Cosmetology-Mesa']]
# Out:
#                                         CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# INSTNM
# University of Alaska Anchorage     Anchorage     AK   0.0      0.0        0.0
# Avalon School of Cosmetology-Mesa       Mesa     AZ   0.0      0.0        0.0
#
#                                    RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# University of Alaska Anchorage            0       NaN       NaN           0.0
# Avalon School of Cosmetology-Mesa         0       NaN       NaN           0.0
#
#                                       UGDS         ...          UGDS_2MOR  \
# INSTNM                                             ...
# University of Alaska Anchorage     12865.0         ...              0.098
# Avalon School of Cosmetology-Mesa    360.0         ...              0.025
#
#                                    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# University of Alaska Anchorage       0.0181     0.0457    0.4539         1
# ...

# %%
labels_test = college.iloc[[3, 10, 15]].index.tolist()

# %%
college.loc[labels_test]
# Out:
#                                                  CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alabama in Huntsville        Huntsville     AL   0.0      0.0
# Birmingham Southern College                Birmingham     AL   0.0      0.0
# James H Faulkner State Community College  Bay Minette     AL   0.0      0.0
#
#                                           WOMENONLY  RELAFFIL  SATVRMID  \
# INSTNM
# University of Alabama in Huntsville             0.0         0     595.0
# Birmingham Southern College                     0.0         1     560.0
# James H Faulkner State Community College        0.0         0       NaN
#
#                                           SATMTMID  DISTANCEONLY    UGDS  \
# INSTNM
# University of Alabama in Huntsville          590.0           0.0  5451.0
# Birmingham Southern College                  560.0           0.0  1180.0
# James H Faulkner State Community College       NaN           0.0  4286.0
#
# ...

# %%
college.loc[:'University of Alabama in Huntsville', :'RELAFFIL']
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL
# INSTNM
# Alabama A & M University                   0.0         0
# University of Alabama at Birmingham        0.0         0
# Amridge University                         0.0         1
# University of Alabama in Huntsville        0.0         0

# %%
college.iloc[:3, :6]
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL
# INSTNM
# Alabama A & M University                   0.0         0
# University of Alabama at Birmingham        0.0         0
# Amridge University                         0.0         1

# %%
college.iloc[:, [4,6]].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %%
col_ind = college.loc[:, ['WOMENONLY','SATVRMID']]

# %%
col_ind.head(1)
# Out:
#                           WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University        0.0     424.0

# %%
col_colm = college.iloc[:, [7,15]].columns.tolist()

# %%
college.loc[['GateWay Community College', 'American Baptist Seminary of the West'],
            ['SATMTMID', 'UGDS_NHPI']]
# Out:
#                                        SATMTMID  UGDS_NHPI
# INSTNM
# GateWay Community College                   NaN     0.0029
# American Baptist Seminary of the West       NaN        NaN

# %%
col_ind = college.iloc[[100, 200],].index.tolist()

# %%
college.loc[col_ind, col_colm]
# Out:
#                                        SATMTMID  UGDS_NHPI
# INSTNM
# GateWay Community College                   NaN     0.0029
# American Baptist Seminary of the West       NaN        NaN

# %%
college.iloc[5, -4]
# Out:
# 0.401

# %%
college.loc['The University of Alabama', 'PCTFLOAN']
# Out:
# 0.401

# %%
college.iloc[90:80:-2, 5]
# Out:
# INSTNM
# Empire Beauty School-Flagstaff     0
# Charles of Italy Beauty College    0
# Central Arizona College            0
# University of Arizona              0
# Arizona State University-Tempe     0
# Name: RELAFFIL, dtype: int64

# %%
col_start = college.columns.get_loc('UGDS_WHITE')

# %%
col_stop = college.columns.get_loc('UGDS_UNKN') + 1

# %%
college.iloc[:5, col_start:col_stop]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college = college.sort_index()

# %%
college.loc['By':'D'].head(50)
# Out:
#                                                                  CITY STABBR  \
# INSTNM
# Byzantine Catholic Seminary of Saints Cyril and...         Pittsburgh     PA
# CALC Institute of Technology                                    Alton     IL
# CBD College                                               Los Angeles     CA
# CBTS - Wisconsin                                            Elm Grove     WI
# CC's Cosmetology College                                        Tulsa     OK
# CC's Cosmetology College-Texarkana                          Texarkana     TX
# CCI Training Center                                            Dallas     TX
# CCI Training Center-Arlington                               Arlington     TX
# CDA Technical Institute                                  Jacksonville     FL
# CDE Career Institute                                     Tannersville     PA
# CES College                                                   Burbank     CA
# ...
