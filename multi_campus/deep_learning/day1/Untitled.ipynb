# %%
import pandas as pd

# %%
for i in range (1900, 2020, 10):
    try:
        globals()["family_{}".format("%d" %i)] = pd.read_csv("%d년_행정구역_기준_가구수_추이.csv" %i , header =1) 
        
    except:
        pass

# %%
for i in range (1900, 2020, 10):
    try:
        globals()["population_{}".format("%d" %i)] = pd.read_csv("%d년_행정구역_기준_인구_추이.csv" %i , header =1)
        
    except:
        pass

# %%
for i in range (1900, 2020, 10):
    try:
        globals()["house_{}".format("%d" %i)] = pd.read_csv("%d년_행정구역_기준_주택수_추이.csv" %i , header =1)
        
    except:
        pass

# %%
population_2010
# Out:
#    행정구역별(시군구)       총인구        남자        여자      총내국인      남자.1      여자.1  \
# 0          전국  48580293  24167098  24413195  47990761  23840896  24149865
# 1       서울특별시   9794304   4803373   4990931   9631482   4726028   4905454
# 2       부산광역시   3414950   1676689   1738261   3393191   1664678   1728513
# 3       대구광역시   2446418   1212584   1233834   2431774   1204428   1227346
# 4       인천광역시   2662509   1334576   1327933   2632035   1315562   1316473
# 5       광주광역시   1475745    729330    746415   1466143    724161    741982
# 6       대전광역시   1501859    750762    751097   1490158    745150    745008
# 7       울산광역시   1082567    557694    524873   1071673    550869    520804
# 8         경기도  11379459   5705613   5673846  11196053   5599570   5596483
# 9         강원도   1471513    738399    733114   1463650    735075    728575
# 10       충청북도   1512157    758214    753943   1495984    748622    747362
# 11       충청남도   2028002   1023882   1004120   2000473   1007454    993019
# ...

# %%
globals()["population_{}".format("%d" %i)] = pd.read_csv("%d년_행정구역_기준_인구_추이.csv" %i , header =1)
globals()["house_{}".format("%d" %i)] = pd.read_csv("%d년_행정구역_기준_주택수_추이.csv" %i , header =1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-b19acd3abf6d> in <module>()
# ----> 1 house_2000
#
# NameError: name 'house_2000' is not defined

# %%
for i in range (1900, 2020, 10):
    print(i)
# Out:
# 1900
# 1910
# 1920
# 1930
# 1940
# 1950
# 1960
# 1970
# 1980
# 1990
# 2000
# 2010
